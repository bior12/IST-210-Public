# %% [markdown]
# IDEA 1: Airport
#
#
#
# a.
# > i. our idea would be to simulate how an airport runs and its day-to-day operations
#
# > ii. while this may not be unique as in it doesn't exist already, it seems to be a very scalable idea that has a lot of potential for growth.
#
# > iii. we are not coming up with a unique idea for this because borrowing from an already existing system would allow us to more closely model an acurite database for our project
#
#
# tables:
#
# >**- Checkbook**
# >- Description: stores profits, expenses, profits, etc...
# >- entities: cash in safe, amount in bank account
# >- attributes: new profit, where the money goes
#
# | month     | revenue (in thousands) | machinery expenses (in thousands) | salary costs (in thousands) |
# |-----------|------------------------|-----------------------------------|-----------------------------|
# | January   | 12                     | 2                                 | 3                           |
# | February  | 14                     | 3                                 | 3                           |
# | March     | 15                     | 5                                 | 3                           |
# | April     | 12                     | 3                                 | 3                           |
# | May       | 16                     | 5                                 | 3                           |
# | June      | 17                     | 6                                 | 3                           |
# | July      | 16                     | 5                                 | 3                           |
# | August    | 12                     | 2                                 | 3                           |
# | September | 8                      | 1                                 | 3                           |
# | October   | 9                      | 1                                 | 3                           |
# | November  | 10                     | 2                                 | 3                           |
# | December  | 11                     | 2                                 | 3                           |
#
#
#
#
#
# >**- Customers**
# >- Description: stores person's name and seat number
# >- This table will be our "end-user" table, and will be unique for every plane.
# >- This will change based on our operation hours table because multiple different flights will be arriving per day.
# >- entities: people
# >- attributes: seat number, name, class
# >- Constraints: classes must be either economy, business, or first, seat number  < 1000
#
# | person (id number) | seat number | name          | class         |
# |--------------------|-------------|---------------|---------------|
# | 1234567            | A23         | John Smith    | First Class   |
# | 2134156            | c10         | Tommy Stevens | Economy Class |
# |                    |             |               |               |
#
#
# >**- Operational Hours**
# >- Description: stores when the airport is open and it's different operational hours for holidays, special occasions
# >- entities: days of the week
# >- attributes: hours open that day, is it a holiday
# >- Constraints: hours cannot open on holidays
#
# |    Day    | Open Time | Close Time | Holiday |
# |-----------|-----------|------------|---------|
# | Monday    | 8 AM      | 11 PM      | N       |
# | Tuesday   | 8 AM      | 11 PM      | N       |
# | Wednesday | 8 AM      | 11 PM      | N       |
# | Thursday  | 8 AM      | 11 PM      | N       |
# | Friday    | 8 AM      | 11 PM      | N       |
# | Saturday  | 10 AM     | 10 PM      | N       |
# | Sunday    | 10 AM     | 10 PM      | N       |
#
#
# >**- Planes**
# >- Description: stores the different types of planes the airport uses
# >- entities: plane
# >- attributes: seats, size, food on plane, max altitude, fuel capacity
# >- Constraints: max altitude < 50000 ft, fuel capacity > 50 gallons
#
# | Planes         | seats | cruising altitude | food on plane          | fuel capacity  | flight ID number |
# |----------------|-------|-------------------|------------------------|----------------|------------------|
# | boeing 787     | 550   | 30,000 feet       | International Cuisine  | 200,000 litres | EY210            |
# | airbus A380    | 737   | 45,000 feet       | Mediterranean Cuisine  | 323,000 litres | EY217            |
# | Dreamliner 788 | 368   | 25,000 feet       | vegetarian meals       | 120,000 litres | EY662            |
# | Star Jet       | 80    | 18,000 feet       | Sacks                  |  50,000 Litres | EY999            |
#
#
# >**- Flight Paths**
# >- Description: stores the different plane flight paths
# >- entities: flight path
# >- attributes: duration, start location, end location, altitude, overseas
# >- Constraints: duration <25 hrs, start and end location must be at airport
# >- attributes: durration, start location, end location, altitude, overseas
#
# | Flight path ID  | Start Location           | End Location             | Duration | Altitude | Overseas |
# |-----------------|--------------------------|--------------------------|----------|----------|----------|
# | BA2364          | New York, USA            | Paris, France            | 7h 20 m  | 37,000   | Y        |
# | CX7209          | London,England           | Washington DC, USA       | 8 h 10 m | 37,000   | Y        |
# | DW5263          | Los Angeles, California  | Providence, Rhode Island | 5 h 40 m | 37,000   | N        |
#
# \
#
# <center>
# <img src="data:image/png;base64,..." style="cursor:pointer;max-width:100%;" onclick="(function(img){if(img.wnd!=null&&!img.wnd.closed){img.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&&evt.source==img.wnd){img.wnd.postMessage(decodeURIComponent(img.getAttribute('src')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);img.wnd=window.open('https://www.draw.io/?client=1&lightbox=1&edit=_blank');}})(this);"/>
# </center>

# %% [markdown]
# IDEA 2: Casino
#
# >i. our idea would be to simulate how a casino runs and its day-to-day operations
#
# >ii. while this may not be unique as in it doesn't exist already, it seems to be a very scalable idea that has a lot of potential for growth.
#
# >iii. we are not coming up with a unique idea for this because borrowing from an already existing system would allow us to more closely model an acurite database for our project
#
# tables:
#
# >**- checkbook (money)**
# >>- Description: stores profits, expenses, profits, etc...
# >>- entities: cash in safe, amount in bank account
# >>- attributes: new profit, where the money goes
# >>- constraints: must be in USD, cannot be counterfeit
#
# | month     | revenue (in thousands) | machinery expenses (in thousands) | salary costs (in thousands) |
# |-----------|------------------------|-----------------------------------|-----------------------------|
# | January   | 12                     | 2                                 | 3                           |
# | February  | 14                     | 3                                 | 3                           |
# | March     | 15                     | 5                                 | 3                           |
# | April     | 12                     | 3                                 | 3                           |
# | May       | 16                     | 5                                 | 3                           |
# | June      | 17                     | 6                                 | 3                           |
# | July      | 16                     | 5                                 | 3                           |
# | August    | 12                     | 2                                 | 3                           |
# | September | 8                      | 1                                 | 3                           |
# | October   | 9                      | 1                                 | 3                           |
# | November  | 10                     | 2                                 | 3                           |
# | December  | 11                     | 2                                 | 3                           |
#
#
# >**- Customers**
#
# >>- Description: stores person's name and how often they play at the casino
# >>- This table will be our "end-user" table, and will keep real time data on customers.
# >>- This will change based on our operation hours table because the casino will have modified hours on holidays and weekends.
# >>- entities: people
# >>- attributes: seat number, name, class
# >>- Constraints: customers must be older than 18
#
# | person (id number) | age | time spent at casino (hours) |
# |--------------------|-----|------------------------------|
# | 1234223            | 32  | 2301                         |
# | 2134123            | 20  | 100                          |
#
#
# >**- operational hours**
#
# >>- Description: stores when the airport is open and it's different operational hours for holidays, special occasions
# >>- entities: days of the week
# >>- attributes: hours open that day, is it a holiday
# >>- constraints: hours cannot open on holidays
#
# |    Day    | Open Time | Close Time | Holiday |
# |-----------|-----------|------------|---------|
# | Monday    | 8 AM      | 11 PM      | N       |
# | Tuesday   | 8 AM      | 11 PM      | N       |
# | Wednesday | 8 AM      | 11 PM      | N       |
# | Thursday  | 8 AM      | 11 PM      | N       |
# | Friday    | 8 AM      | 11 PM      | N       |
# | Saturday  | 10 AM     | 10 PM      | N       |
# | Sunday    | 10 AM     | 10 PM      | N       |
#
# >**- Floor activities**
#
# >>- Description: stores the different types of machines / tables on each floor of the casino
# >>- Entities: machine / table
# >>- Attributes: floor number, type (machine/table), type (specific machine / specific table), how many occupants, does it require a dealer (for tables)
# >>- Constraints: a machine cannot have a dealer
#
# |         | Type | Floor Number | Number of Occupants | Requires a dealer |
# |---------|------|--------------|---------------------|-------------------|
# | Machine | DATA | 10           | DATA                | No                |
# | Table   | DATA | 5            | DATA                | Yes               |
#
#
# >**- table stakes**
# >>- Descrition: stores how much the skates are for each of the tables
# >>- Entities: type of table
# >>- Attributes: starting bid, buy-in, type of chips used
# >>- Constraints: starting bid geater than or equal 5 dallors, chip value must be $5, $10, $25, $100, $500, or $1000 and from own casino
#
# | Table Stakes | Starting Bid | Buy-In | Type Of Chips Used |
# |--------------|--------------|--------|--------------------|
# | \$10         | \$5          | \$15   | \$5                |
# | \$240        | \$200        | \$350  | \$10               |
# | \$125        | \$100        | \$150  | \$25               |
# | \$500        | \$300        | \$700  | \$100              |
# | \$1000       | \$500        | \$1500 | \$500              |
# | \$2000       | \$1000       | \$3000 | \$1000             |
#
# \
# \
# \
# <center>
# <img src="data:image/png;base64,..." style="cursor:pointer;max-width:100%;" onclick="(function(img){if(img.wnd!=null&&!img.wnd.closed){img.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&&evt.source==img.wnd){img.wnd.postMessage(decodeURIComponent(img.getAttribute('src')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);img.wnd=window.open('https://www.draw.io/?client=1&lightbox=1&edit=_blank');}})(this);"/>
# <center>

# %% [markdown]
# IDEA 3: Carwash
# >i. our idea would be to simulate running a car wash
#
# >ii. By closely analyzing the details of the car wash, we can determine what types of washes are the most
# profitable, thus figure out what types of machinery to invest in
#
# >iii. we are borrowing an idea as car washes are quite common and already exist. A typical day might involve washing the cars of various customers and using different machines to wash them depending on the type of car wash purchased
#
# tables:
# >**- checkbook (money)**
#
# >- Description: stores profits, expenses, profits, etc...
# >- entities: cash in safe, amount in bank account
# >- attributes: new profit, where the money goes
# >- constraints: must be in USD, cannot be counterfeit
#
# | month     | revenue (in thousands) | machinery expenses (in thousands) | salary costs (in thousands) |
# |-----------|------------------------|-----------------------------------|-----------------------------|
# | January   | 12                     | 2                                 | 3                           |
# | February  | 14                     | 3                                 | 3                           |
# | March     | 15                     | 5                                 | 3                           |
# | April     | 12                     | 3                                 | 3                           |
# | May       | 16                     | 5                                 | 3                           |
# | June      | 17                     | 6                                 | 3                           |
# | July      | 16                     | 5                                 | 3                           |
# | August    | 12                     | 2                                 | 3                           |
# | September | 8                      | 1                                 | 3                           |
# | October   | 9                      | 1                                 | 3                           |
# | November  | 10                     | 2                                 | 3                           |
# | December  | 11                     | 2                                 | 3                           |
#
#
# >**- customers**
# >- Description: customers who comes to the carwash, and what services they receive
# >- entities: people
# >- attributes: service requested, name, type of car
# >- Constraints: car cannot have broken glass, cannot be motorcycle
#
# | person (id number) | name         | service requested | type of car |
# |--------------------|--------------|-------------------|-------------|
# | 1234223            | John Smith   | waterless wash    | sedan       |
# | 2134123            | Tyler Farmer | automatic wash    | prius       |
#
#
# >**- operational hours**
# >- Description: stores when the carwash is open, and it’s different operational hours on special occasions
# >- entities: days of the week
# >- attributes: hours open that day, is it a holiday?
# >- constraints: cannot open on holidays
#
# |    Day    | Open Time | Close Time | Holiday |
# |-----------|-----------|------------|---------|
# | Monday    | 8 AM      | 11 PM      | N       |
# | Tuesday   | 8 AM      | 11 PM      | N       |
# | Wednesday | 8 AM      | 11 PM      | N       |
# | Thursday  | 8 AM      | 11 PM      | N       |
# | Friday    | 8 AM      | 11 PM      | N       |
# | Saturday  | 10 AM     | 10 PM      | N       |
# | Sunday    | 10 AM     | 10 PM      | N       |
#
# >**- types of wash**
# >- Description: types of car washes available for purchase
# >- Entities: car washes
# >- Attributes: cost,  duration of wash, machinery used to wash car
# >- Constraints: cost < $10, duration < 10 mins
#
# | types of wash | cost | duration  | machinery used                |
# |---------------|------|-----------|-------------------------------|
# | speed wash    | 3    | 2 min     | pressure washer               |
# | basic wash    | 5    | 10        | pressure washer, soap sprayer |
# | premium wash  | 10   | 12        | all machines                  |
#
#
# >**- list of equipment**
# >- Description: list of equipment used to wash the cars
# >- Entities: equipment
# >- Attributes: cost,  material used (water, soap, etc),  functionality
# >- Constraints: water usage < 50 gallons per wash, energy efficient
#
# | equipment       | cost | materials used                  | functionality  |
# |-----------------|------|---------------------------------|----------------|
# | pressure washer | 250  | 10 gallons of water             | sprays water   |
# | soap sprayer    | 500  | 1 oz of soup, 1 gallon of water | applies soap   |
# | blow dryer      | 1000 | none                            | blow drys cars |
#
# \
#
# \
#
# <center>
# <img src="data:image/png;base64,..." style="cursor:pointer;max-width:100%;" onclick="(function(img){if(img.wnd!=null&&!img.wnd.closed){img.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&&evt.source==img.wnd){img.wnd.postMessage(decodeURIComponent(img.getAttribute('src')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);img.wnd=window.open('https://www.draw.io/?client=1&lightbox=1&edit=_blank');}})(this);"/>

# %% [markdown]
# ________________________________________________________________________________________
