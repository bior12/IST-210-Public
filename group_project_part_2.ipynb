# %% [markdown]
# IDEA 1: Airport
# >i. our idea would be to simulate how an airport runs and its day-to-day operations
# This includes how the airport runs every day and the happenings
#
# >>We are looking to include multiple facets of what happens in the airport to the best of our abilities like simulating the airways, types of planes, employees, flight routes, customers, cash flow, ect...
#
# >ii. while this may not be unique as in it doesn't exist already, it seems to be a very scalable idea that has
#
# >>a lot of potential for growth.
#
# >iii. we are not coming up with a unique idea for this because borrowing from an already existing system would allow us to more closely model an accurate database for our project
#
# >Iv. A Data Model of an airport can help airport managers know which airline is bringing in more customers or attracting more people to the airport.
#
# **tables:**
# - checkbook (money)
#
# >- Description: stores profits, expenses, profits, etc...
# >- Entities: months
# >- Attributes: new profit, where the money goes
# >- Constraints:
#
# | month  | revenue (\$ in thousands) | machinery expenses (\$ in thousands) | salary costs (\$in thousands) |
# |-----------|------------------------|-----------------------------------|-----------------------------|
# | January   | 12                     | 2                                 | 3                           |
# | February  | 14                     | 3                                 | 3                           |
# | March     | 15                     | 5                                 | 3                           |
# | April     | 12                     | 3                                 | 3                           |
# | May       | 16                     | 5                                 | 3                           |
# | June      | 17                     | 6                                 | 3                           |
# | July      | 16                     | 5                                 | 3                           |
# | August    | 12                     | 2                                 | 3                           |
# | September | 8                      | 1                                 | 3                           |
# | October   | 9                      | 1                                 | 3                           |
# | November  | 10                     | 2                                 | 3                           |
# | December  | 11                     | 2                                 | 3                           |
#
#
# \
# - customers per plane
#
# >- Description: stores person's name and seat number, this can be used to keep track of custim
# This table will be our "end-user" table, and will be unique for every plane.
# This will change based on our operation hours table because multiple different flights will be arriving per day.
# >- entities: people
# >- attributes: seat number, name, class
# >- Constraints: classes must be either economy, business, or first, seat number  < 1000
#
# | person (id number) | seat number | name          | class         |
# |--------------------|-------------|---------------|---------------|
# | 1234567            | A23         | John Smith    | First Class   |
# | 2134156            | c10         | Tommy Stevens | Economy Class |
# |                    |             |               |               |
#
# \
# - operational hours
#
# >- Description: stores when the airport is open and it's different operational hours for holidays, special occasions
# >- entities: days of the week
# >- attributes: hours open that day, is it a holiday
# >- Constraints: hours cannot open on holidays
#
# |           | Open Time | Close Time | Holiday |
# |-----------|-----------|------------|---------|
# | Monday    | 8 AM      | 11 PM      | N       |
# | Tuesday   | 8 AM      | 11 PM      | N       |
# | Wednesday | 8 AM      | 11 PM      | N       |
# | Thursday  | 8 AM      | 11 PM      | N       |
# | Friday    | 8 AM      | 11 PM      | N       |
# | Saturday  | 10 AM     | 10 PM      | N       |
# | Sunday    | 10 AM     | 10 PM      | N       |
#
# \
# - planes
#
# >- Description: stores the different types of planes the airport uses
# >- entities: plane
# >- attributes: seats, size, food on plane, max altitude, fuel capacity
# >- Constraints: cruising altitude < 50000 ft, fuel capacity > 10,000 litres
#
# | Planes         | seats | cruising altitude | food on plane          | fuel capacity  | flight ID number |
# |----------------|-------|-------------------|------------------------|----------------|------------------|
# | boeing 787     | 550   | 30,000 feet       | International Cuisine  | 200,000 litres | EY210            |
# | airbus A380    | 737   | 45,000 feet       | Mediterranean Cuisine  | 323,000 litres | EY217            |
# | Dreamliner 788 | 368   | 25,000 feet       | vegetarian meals       | 120,000 litres | EY662            |
# | Star Jet       | 80    | 18,000 feet       | Sacks                  |  50,000 Litres | EY999            |
#
# \
# - flight paths
#
# >- Description: stores the different plane flight paths
# >- entities: flight path
# >- attributes: duration, start location, end location, altitude, overseas
# >- Constraints: duration <25 hrs, start and end location must be at airport
#
# | Flight path ID  | Start Location           | End Location             | Duration | Altitude | Overseas |
# |-----------------|--------------------------|--------------------------|----------|----------|----------|
# | BA2364          | New York, USA            | Paris, France            | 7h 20 m  | 37,000   | Y        |
# | CX7209          | London,England           | Washington DC, USA       | 8 h 10 m | 37,000   | Y        |
# | DW5263          | Los Angeles, California  | Providence, Rhode Island | 5 h 40 m | 37,000   | N        |
#
# \
# - airlines
#
# >- Description: stores information like lane number, name, number of customers for each airline
# >- Entities: airlines
# >- Attributes: Lane number, Number of customers each airline serves, operational hours, number of flights each day,
# >- Constraints: each airline must have at least one lane
#
#
# |                   | Lane # | Number of flights/day | Number of customers |
# |-------------------|--------|-----------------------|---------------------|
# | United Airlines   | 5      | 11                    | 1000                |
# | American Airlines | 2      | 17                    | 750                 |
# | Delta Airlines    | 1      | 6                     | 500                 |
# | Emirates Airlines | 8      | 15                    | 1200                |
#
# \
# - employees, flight attendant
#
# Description: keeps track of the employees and their attributes
# Entities: flight attendants
# Attributes: salary, job, years worked, work hours per week, age
# Constraints: salary > $35,000, work hours per week > 15, age  < 75
#
# | employee id | name       | salary   | job           | access level | years worked | work hours per week | age |
# |-------------|------------|----------|---------------|--------------|--------------|---------------------|-----|
# | 912144      | John Brown | \$70,100 | Bartender     | 2            | 10           | 40                  | 32  |
# | 129841      | Joe Green  | \$65,100 | Food Server   | 2            | 2            | 40                  | 22  |
# | 802352      | Mary Adams | \$80,600 | Medical Staff | 2            | 5            | 40                  | 30  |
#
# \
# - employees, pilot
# >- Description: keeps track of the employees and their attributes
# >- Entities: pilot
# >- Attributes: salary, job, years worked, work hours per week, age
# >- Constraints: salary > $35,000, work hours per week > 15, age  < 75
#
# | employee id | name       | salary    | job             | access level | years worked | work hours per week | age |
# |-------------|------------|-----------|-----------------|--------------|--------------|---------------------|-----|
# | 124125      | John Smith | \$120,100 | Senior Pilot    | 3            | 15           | 40                  | 38  |
# | 251215      | Joe Doe    | \$25,100  | Trainee         | 3            | 0            | 18                  | 22  |
# | 456858      | Mary Doe   | \$80,000  | Part-time Pilot | 3            | 9            | 40                  | 30  |
#
# \
# - employees, janitor
#
# >- Description: keeps track of the employees and their attributes
# >- Entities: janitor
# >- Attributes: salary, job, years worked, work hours per week, age
# >- Constraints: salary > $35,000, work hours per week > 15, age  < 75
#
#
# | employee ID | Name | salary | job | years worked | work hours per week | age | access level |
# |-------------|-------------|----------|--------------|--------------|---------------------|-----|--------------|
# | 123354 | John Doe | \$40,000 | Maintenance  | 5 | 40 | 25 | 4 |
# | 545321 | Joe Dude | \$45,000 | Plumber | 10 | 40 | 30 | 4 |
# | 423567 | Mark Target | \$43,000 | Maintenance | 3 | 40 | 23 | 4 |
#
#
# \
#
# <center>
# <img src="data:image/png;base64,..." style="cursor:pointer;max-width:100%;" onclick="(function(img){if(img.wnd!=null&&!img.wnd.closed){img.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&&evt.source==img.wnd){img.wnd.postMessage(decodeURIComponent(img.getAttribute('src')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);img.wnd=window.open('https://www.draw.io/?client=1&lightbox=1&edit=_blank');}})(this);"/>
